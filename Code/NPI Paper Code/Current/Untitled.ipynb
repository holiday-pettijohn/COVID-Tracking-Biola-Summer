# %%
from scipy.stats import poisson
import numpy as np
import matplotlib.pyplot as plt
import random
mu=10
rv=poisson(mu)
x=np.arange(0,25)
y=rv.pmf(x)
y=y/sum(y)
plt.plot(x,y)


zz=np.random.randint(0,32,(200))
cv=np.convolve(zz, y)
plt.plot(zz)
plt.plot(cv)
